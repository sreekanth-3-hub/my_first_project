# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# [link text](https://seaborn.pydata.org/tutorial/categorical.html#categorical-tutorial)

# %% [markdown]
# # Checking Matplotlib Version

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.6.2

# %% [markdown]
# # Matplotlib Pyplot
#
# - Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# - Example

# %%
xpoints = [1, 3, 5, 7,3 , 2, 5] 
ypoints = [2, 5, 0, 3, 9, 4, 18] #coordinates for ploting
plt.plot(xpoints, ypoints, linestyle = 'dotted')

# %% [markdown]
# - *Matplotlib Markers:* use the keyword argument marker to emphasize each point with a specified marker:

# %%
plt.plot(xpoints, ypoints, marker = '>') #try : 'v' , '^', '<', '>', '1', 'D', '|' etc

# %% [markdown]
# - Linestyle

# %%
plt.plot(xpoints, ypoints, linestyle = 'dotted' , marker = 'o') # Try: 'dashed', 'dashdot', 'None'

# %%
plt.xlabel('erkpg')
plt.ylabel('fkpq')
plt.plot(xpoints, ypoints, linestyle = 'None' , marker = 'o', markersize = 30) # Try: 'dashed', 'dashdot', 'None'

# %%
plt.plot(xpoints, ypoints, 'k+')

# %% [markdown]
# - Create Labels
#
# Use *xlabel()* and ylabel() functions to set a label for the x- and y-axis.

# %%
plt.xlabel('X - Anything')
plt.ylabel('Y - Anything')
# Out:
# Text(0, 0.5, 'Y - Anything')

# %% [markdown]
# - Create a Title

# %%
plt.title("Any Title")
# Out:
# Text(0.5, 1.0, 'Any Title')

# %% [markdown]
# - Set Font size for Title and Labels

# %%
plt.title("Any Title", fontdict = {'color':'blue','size':20})
plt.xlabel("X - Anything", fontdict = {'color':'blue','size':20})
plt.ylabel("Y - Anything", fontdict = {'color':'blue','size':20})
plt.plot(xpoints, ypoints)

# %% [markdown]
# - Position of Title

# %%
plt.title("Any Title", loc = 'left', fontdict = {'color':'blue','size':20})
# Out:
# Text(0.0, 1.0, 'Any Title')

# %% [markdown]
# - Grid Lines

# %%
plt.grid()
# plt.plot(xpoints, ypoints)

# %%
plt.grid(axis = 'x')

# %%
plt.grid(color = 'blue', linestyle = '--', linewidth = 0.5)

# %% [markdown]
# - subplots() Function

# %%
plt.subplot(4, 2, 1)
plt.plot(xpoints, ypoints, linestyle = 'dotted' , marker = 'o')
#the figure has 1 row, 2 columns, and this plot is the first plot.

plt.subplot(4, 2, 1)
# plt.plot(xpoints, ypoints, marker = 'o')
#the figure has 1 row, 2 columns, and this plot is the second plot.
# Out:
# <AxesSubplot: >

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("INCOME")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("SALES")

plt.suptitle("MY SHOP" )      # Super Title
plt.show()

# %% [markdown]
# # Multiline Plot

# %%
# line 1 points
x1 = [10,20,30]
y1 = [20,40,10]
# plotting the line 1 points 
plt.plot(x1, y1, label = "line 1")
# line 2 points
x2 = [10,20,30]
y2 = [40,10,30]
# plotting the line 2 points 
plt.plot(x2, y2, label = "line 2")
plt.xlabel('x - axis')
# Set the y axis label of the current axis.
plt.ylabel('y - axis')
# Set a title of the current axes.
plt.title('Two or more lines on same plot with suitable legends ')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()

# %% [markdown]
# # Scatter plot

# %%
x = list([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = list([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
# plt.subplot(2, 2, 1)
plt.scatter(x, y)


x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
# plt.subplot(2, 1, 2)
plt.scatter(x, y)

plt.show()

# %%
df = pd.DataFrame({
    'Name': ['A', 'B', 'C', 'A', 'A', 'A', 'C', 'B'],
    'Age': [45, 38, 90, 44, 67, 87, 55, 78]})
df
# Out:
#   Name  Age
# 0    A   45
# 1    B   38
# 2    C   90
# 3    A   44
# 4    A   67
# 5    A   87
# 6    C   55
# 7    B   78

# %%
df['Age'].hist() #Pure pandas plotting
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Bar Plot

# %%
x = np.array(["A", "B", "C", "D"]) #Categorical data => bar plot
y = np.array([3, 8, 1, 10])

plt.bar(x,y) #Bar plot using matplotlib

plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])


plt.barh(x, y)    # horizontal bars
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red")  # Bar Colour
plt.show()

# %%
plt.bar(x, y, width = 0.1)   # Bar Width 
plt.show()

# %% [markdown]
# - Histograms

# %%
x.shape
# Out:
# (4,)

# %%
x
# Out:
# array(['A', 'B', 'C', 'D'], dtype='<U1')

# %%
x
# Out:
# array(['A', 'B', 'C', 'D'], dtype='<U1')

# %%
x.min(), x.max()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 x.min(), x.max()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\core\_methods.py:45, in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# UFuncTypeError: ufunc 'minimum' did not contain a loop with signature matching types (dtype('<U1'), dtype('<U1')) -> None

# %%
np.random.normal(0, 1, 5)
# Out:
# array([-0.44820365,  0.71523881,  0.96273163, -0.22328123, -1.19125046])

# %%
x = np.random.normal(-5, 10, 2000) #x contains 2000 random values. Normal/Gaussian distribution. 170 is mean, 10 is standard deviation
plt.hist(x, bins =10)
plt.show()

# %% [markdown]
# # Pie Charts

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# - Start Angle
#
# As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a *startangle* parameter.

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# # Explode

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.5, 0.1, 0.3, 0.4]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# - Legend

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, autopct='%.3i')
plt.legend()
plt.show()

# %% [markdown]
# # **Seaborn**

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %% [markdown]
# - Seaborn comes with a few important datasets in the library. When Seaborn is installed, the datasets download automatically.

# %%
sns.get_dataset_names()    # view all the available data sets in the Seaborn library
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('iris')  #Loading a dataset
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (8, 2)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# - Histogram by Seaborn

# %%
sns.distplot(df['petal_length'],)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %% [markdown]
# - Kernel Density Estimates:
#
# > A way to estimate the probability density function of a continuous random variable.

# %%
sns.distplot(df['petal_length'],hist=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
sns.distplot(df['petal_length'],hist=True, kde=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %% [markdown]
# # Plotting Bivariate Distribution
#
# - By Scatter Plot & Scatter Plot

# %%
df.shape
# Out:
# (150, 5)

# %%
sns.jointplot(x = 'petal_length',y = 'petal_width',data = df)

# %% [markdown]
# - By Hexbin Plot
#
# Hexagonal binning is used in bivariate data analysis when the data is sparse in density i.e., when the data is very scattered and difficult to analyze through scatterplots.
#
# An addition parameter called ‘kind’ and value ‘hex’ plots the hexbin plot.

# %%
sns.jointplot(x = 'petal_length',y = 'petal_width',data = df,kind = 'hex')

# %% [markdown]
# - Kernel Density Estimation

# %%
sns.jointplot(x = 'petal_length',y = 'petal_width',data = df, kind = 'kde')

# %% [markdown]
# # Pair plot
#
#
# - To plot multiple pairwise bivariate distributions in a dataset

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue = 'species',diag_kind = "kde",kind = "scatter",palette = "Accent")  

# hue: Variable , diag_kind : Kind of plot for the diagonal subplots. {‘hist’, ‘kde’} , kind = {‘scatter’, ‘reg’}, palette: set Colour

# %% [markdown]
# # Categorical scatterplots:

# %% [markdown]
# # Strip plot
#
# - When one or both the variables are categorical, we use plots like striplot(), swarmplot()
# - [link text](https://seaborn.pydata.org/generated/seaborn.stripplot.html#seaborn.stripplot)

# %%
import seaborn as sns

# %%
df1 = sns.load_dataset("tips")
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 print(df1)
#
# NameError: name 'df1' is not defined

# %%
# Draw a single horizontal strip plot:
sns.stripplot(x=df1["total_bill"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 2
#       1 # Draw a single horizontal strip plot:
# ----> 2 sns.stripplot(x=df1["total_bill"])
#
# NameError: name 'sns' is not defined

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
#Group the strips by a categorical variable:
sns.stripplot(x="day", y="total_bill", data=df1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 #Group the strips by a categorical variable:
# ----> 2 sns.stripplot(x="day", y="total_bill", data=df1)
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # Swarm plot
#
# - This function positions each point of scatter plot on the categorical axis and thereby avoids overlapping points
# - Does not scale well to large numbers of observations
# - [link text](https://seaborn.pydata.org/generated/seaborn.swarmplot.html#seaborn.swarmplot)

# %%
sns.swarmplot(x=df1["total_bill"])   #Single horizontal swarm plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 sns.swarmplot(x=df1["total_bill"])   #Single horizontal swarm plot
#
# NameError: name 'sns' is not defined

# %%
sns.swarmplot(x="day", y="total_bill", data=df1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 sns.swarmplot(x="day", y="total_bill", data=df1)
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # Categorical distribution plots:

# %% [markdown]
# # Box Plot
#
# - Show distributions with respect to categories
# - A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.
# - [link text](https://seaborn.pydata.org/tutorial/categorical.html#categorical-tutorial)

# %%
sns.boxplot(x=df1["total_bill"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 sns.boxplot(x=df1["total_bill"])
#
# NameError: name 'sns' is not defined

# %%
import seaborn as sas

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker", data=df1, palette="Set3")  # Two categorical variables: day & smoker

# %%
sns.boxplot(x="time", y="tip", data=df1, order=["Dinner", "Lunch"]) # Order passed

# %%
# Plot both Boxplot & Swarmplot for better understanding 
ax = sns.boxplot(x="day", y="total_bill", data=df1)
ax = sns.swarmplot(x="day", y="total_bill", data=df1, color=".25")

# %% [markdown]
# # Violin plot
#
# - Combination of boxplot and kernel density estimate
# - It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared. Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a kernel density estimation of the underlying distribution.
# - [link text](https://seaborn.pydata.org/generated/seaborn.violinplot.html#seaborn.violinplot)

# %%
sns.violinplot(x=df1["total_bill"])   #  single horizontal violinplot

# %%
sns.violinplot(x="day", y="total_bill", data=df1)

# %% [markdown]
# # Count plot
# - Counts of observations in each categorical bin using bars.
# - [link text](https://seaborn.pydata.org/generated/seaborn.countplot.html#seaborn.countplot)

# %%
df2 = sns.load_dataset("titanic")
sns.countplot(x="class", data=df2)  # value counts for a single categorical variable

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %%
sns.countplot(x="class", hue="who", data=df3)   #value counts for two categorical variables:

# %% [markdown]
# # Heat Map

# %%
nparr = np.random.rand(10, 12) #returns 10x12 of random floating numbers with uniform distribution in the range 0 to 1
nparr
# Out:
# array([[0.82392531, 0.02571233, 0.83944806, 0.56661983, 0.90630055,
#         0.29313102, 0.01050935, 0.4763386 , 0.0519648 , 0.35904671,
#         0.35692634, 0.55654071],
#        [0.02835172, 0.32905501, 0.75113404, 0.98662446, 0.31124124,
#         0.52840182, 0.2813773 , 0.96804337, 0.35956108, 0.34435007,
#         0.99867213, 0.15420815],
#        [0.30844805, 0.66629627, 0.19110438, 0.95331735, 0.31810142,
#         0.10826126, 0.18131965, 0.32773212, 0.07293212, 0.21190975,
#         0.33174933, 0.63786076],
#        [0.54698282, 0.31464946, 0.32192215, 0.9151656 , 0.85107866,
#         0.30604232, 0.67284135, 0.52134784, 0.23893547, 0.64363092,
#         0.58394718, 0.68230065],
#        [0.63993538, 0.51571436, 0.47194857, 0.00142548, 0.68925907,
#         0.43555478, 0.24946439, 0.34547777, 0.58336348, 0.85629652,
#         0.74673087, 0.00781851],
#        [0.77705159, 0.07035704, 0.99887379, 0.50124263, 0.54269353,
# ...

# %%
nparr.shape
# Out:
# (10, 12)

# %%
sns.heatmap(nparr)   # heatmap for a numpy array

# %%
flights = sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights = flights.pivot("month", "year", "passengers")
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
ax = sns.heatmap(flights)

# %%
#Annotate each cell with the numeric value
sns.heatmap(flights, annot=True,  fmt="d")

# %%
sns.heatmap(flights, linewidths=.5)      #Add lines between each cell
